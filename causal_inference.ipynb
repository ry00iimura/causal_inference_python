# %% [markdown]
# # SEM

# %%
# %load_ext rpy2.ipython #rpy2をJupyterのNotebook上で使えるようにマジックコマンドを記述する

# %%
# read libraries
import numpy as np
import pandas as pd
from semopy import Model
from semopy import Optimizer
from semopy.inspector import inspect
import semopy.stats

# %%
# The first step build a model
""" 
~は因果関係(左辺←右辺)を意味する
~~は各変数の分散
=~は潜在変数
"""
mod = """ x1 ~ x2 + x3
          x3 ~ x2 + eta1
          eta1 =~ y1 + y2 + y3
          eta1 ~ x1
      """
model = Model(mod)

# %%
# The second step - read a dataset
data = pd.DataFrame(index = [i for i in range(10)],columns = ['x1','x2','x3','y1','y2','y3'],data = np.random.randn(10,6))
model.load_dataset(data)

# %%
# The third step fit the model
opt = Optimizer(model)
objective_function_value = opt.optimize()

# %%
result = inspect(opt)
result
# Out:
#     lval  op  rval  Estimate   Std. Err   z-value   p-value
# 0     x1   ~    x2  0.079259   0.188498  0.420476  0.674138
# 1     x1   ~    x3  0.503419   1.037831  0.485069  0.627628
# 2     x3   ~    x2  0.128174   0.428116   0.29939  0.764642
# 3     x3   ~  eta1 -9.362461   28.38082 -0.329887  0.741485
# 4   eta1   ~    x1  0.113103   0.286541  0.394718  0.693051
# 5     y1   ~  eta1  1.000000          -         -         -
# 6     y2   ~  eta1 -4.586116    8.90448 -0.515035  0.606529
# 7     y3   ~  eta1  9.438466  18.501184  0.510155  0.609943
# 8     x3  ~~    x3  2.085881   3.783666  0.551286  0.581438
# 9   eta1  ~~  eta1  0.009222   0.036364  0.253596  0.799807
# 10    x1  ~~    x1  0.680886    1.02257  0.665858  0.505502
# 11    y3  ~~    y3  0.000000   0.610354       0.0       1.0
# 12    y2  ~~    y2  0.756796   0.367849  2.057351  0.039652
# 13    y1  ~~    y1  0.368447   0.164917  2.234137  0.025474

# %%
# 評価指標による評価
# pd.DataFrame(ParameterStatistics(result['Value'],result['SE'],result['Z-score'],result['P-value']))
# agfi = semopy.stats.calc_agfi(opt)
# aic = semopy.stats.calc_aic(opt)
# cfi = semopy.stats.calc_cfi(opt)
# chi2 = semopy.stats.calc_chi2(opt)
# gfi = semopy.stats.calc_gfi(opt)
# rmsea = semopy.stats.calc_rmsea(opt)
# print('agfi:{},aic:{},cfi:{},chi2:{},gfi:{},rmsea:{}'.format(agfi,aic,cfi,chi2,gfi,rmsea))

# %%
# 可視化モジュールはあるけど、今使えない状態になっている。
